# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a basic agent.
#
# The goal of this sample is to show you the steps that we will later use in the additional code samples when implementing the different agentic patterns.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
import os 
from typing import Annotated
from openai import AsyncOpenAI

from dotenv import load_dotenv

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## Creating the Client
#
# In this sample, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) for access to the LLM.
#
# The `ai_model_id` is defined as `gpt-4o-mini`. Try changing the model to another model available on the GitHub Models marketplace to see the different results.
#
# For us to use the `Azure Inference SDK` that is used for the `base_url` for GitHub Models, we will use the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) to use Semantic Kernel for other model providers.

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
load_dotenv('../../.env')
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Below we create the Agent called `TravelAgent`.
#
# For this example, we are using very simple instructions. You can change these instructions to see how the agent responds differently.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agent
#
# Now we can run the Agent by defining a thread of type `ChatHistoryAgentThread`.  Any required system messages are provided to the agent's invoke_stream `messages` keyword argument.
#
# After these are defined, we create a `user_inputs` that will be what the user is sending to the agent. In this case, we have set this message to `Plan me a sunny vacation`.
#
# Feel free to change this message to see how the agent responds differently.

# %%
async def main():
    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: ChatHistoryAgentThread | None = None

    user_inputs = [
        "Plan me a day trip.",
        "Suggest an itinerary for a 3-day vacation.",
        "What are some must-see attractions at that destination?",
        "Recommend some local dishes to try while I'm there.",
    ]

    for user_input in user_inputs:
        print(f"# User: {user_input}\n")
        first_chunk = True
        async for response in agent.invoke_stream(
            messages=user_input, thread=thread,
        ):
            # 5. Print the response
            if first_chunk:
                print(f"# {response.name}: ", end="", flush=True)
                first_chunk = False
            print(f"{response}", end="", flush=True)
            thread = response.thread
        print()

    # Clean up the thread
    await thread.delete() if thread else None

await main()
# Out:
# # User: Plan me a day trip.
#
# # TravelAgent: How about a wonderful day trip to Paris, France? Here’s a suggested itinerary:
#
# ### Morning
# - **Breakfast at a Parisian Café:** Start your day with a classic French breakfast of croissants and coffee at a local cafe.
# - **Visit the Eiffel Tower:** Head to the iconic Eiffel Tower. You can either take the lift to the top for stunning views of the city or relax in the gardens around it.
#
# ### Midday
# - **Louvre Museum:** Spend a couple of hours exploring the world's largest art museum. Don't miss the Mona Lisa and the Venus de Milo.
# - **Lunch in Le Marais:** Enjoy lunch in the trendy Le Marais district with its many bistros and eateries. Try a classic French dish like Coq au Vin or Duck Confit.
#
# ### Afternoon
# - **Notre-Dame Cathedral:** Take a stroll to the historic Notre-Dame Cathedral. Even if the interior is restricted, the outside and surrounding areas are beautiful.
# - **Seine River Cruise:** Consider a scenic boat cruise on the Seine River for a different perspective of Paris's landmarks.
#
# ### Evening
# - **Dinner at Montmartre:** Head to the artistic district of Montmartre for dinner. You can find many lovely restaurants with views of the city.
# - **Sacré-Cœur Basilica:** End your day with a visit to the Sacré-Cœur Basilica and enjoy the view of the city as it lights up at night.
#
# ### Tips
# - **Transportation:** Use the Paris Metro for easy travel between sites.
# - **Buy Tickets in Advance:** For places like the Louvre and Eiffel Tower to skip long lines.
# - **Enjoy Street Performers:** Keep an eye out for street performances in areas like Montmartre or near the Seine.
#
# This itinerary offers a taste of the culture, art, and cuisine that Paris has to offer in just one day! Enjoy your trip!
# # User: Suggest an itinerary for a 3-day vacation.
#
# # TravelAgent: Here's a fantastic 3-day itinerary for your vacation in Berlin, Germany:
#
# ### Day 1: Explore Historic Berlin
# #### Morning
# - **Brandenburg Gate:** Start your day at this iconic symbol of Berlin. Take time to take photos and enjoy the surrounding park.
# - **Reichstag Building:** Visit the German Parliament building. Make sure to pre-book a time to visit the glass dome for amazing views over the city.
#
# #### Midday
# - **Lunch in Mitte:** Head to the Mitte district for lunch. Try traditional German fare at a local restaurant.
#
# #### Afternoon
# - **Holocaust Memorial:** Visit the poignant memorial dedicated to the victims of the Holocaust located close to the Brandenburg Gate.
# - **Topography of Terror:** Explore the outdoor and indoor exhibitions that cover the history of the Nazis and their atrocities.
#
# #### Evening
# - **Dinner in Kreuzberg:** Enjoy dinner in the trendy Kreuzberg neighborhood, known for its diverse culinary scene.
# - **Nightlife:** Experience Berlin's vibrant nightlife by visiting a bar or club, or take a stroll along the East Side Gallery, a section of the Berlin Wall covered in art.
#
# ---
#
# ### Day 2: Dive into Culture
# #### Morning
# - **Museum Island:** Spend your morning exploring this UNESCO World Heritage site featuring several famous museums, including the Pergamon Museum and the Bode Museum.
#
# #### Midday
# - **Lunch on Museum Island:** Find a café or restaurant nearby for a relaxing lunch.
#
# #### Afternoon
# - **Berlin Cathedral:** Visit the Berlin Cathedral (Berliner Dom) and, if time allows, climb to its dome for fantastic views.
# - **Checkpoint Charlie:** Explore the famous border crossing point between East and West Berlin during the Cold War.
#
# #### Evening
# - **Dinner at a Traditional Beer Garden:** Enjoy a fun dinner at a local beer garden. Sample typical German food and beer.
#
# ---
#
# ### Day 3: Modern Berlin
# #### Morning
# - **Potsdam:** Take a day trip to Potsdam (just a short train ride away). Visit the stunning Sanssouci Palace and its beautiful gardens.
#
# #### Midday
# - **Lunch in Potsdam:** Find a cozy café in Potsdam for lunch.
#
# #### Afternoon
# - **Explore the Parks:** Take time to wander through the extensive parks and gardens, including the New Garden, where you can find the beautiful Cecilienhof Palace.
#
# #### Evening
# - **Return to Berlin:** Head back to Berlin for your last evening.
# - **Farewell Dinner in Friedrichshain:** Choose a nice restaurant to celebrate the conclusion of your trip with delicious food and drink.
#
# ---
#
# ### Tips:
# - **Transportation:** Utilize the U-Bahn and S-Bahn for easy navigation throughout the city and to Potsdam.
# - **Berlin WelcomeCard:** Consider getting a Berlin WelcomeCard for unlimited travel and discounts at attractions.
# - **Reserve Ahead:** For popular attractions, be sure to check if advance booking is necessary.
#
# Berlin combines history, culture, and modernity, so you're in for an enriching experience over your three-day vacation! Enjoy!
# # User: What are some must-see attractions at that destination?
#
# # TravelAgent: Here are some must-see attractions in Berlin, Germany:
#
# 1. **Brandenburg Gate:** An iconic symbol of Berlin and Germany, the Brandenburg Gate is a neoclassical monument that has stood through history and is a must-visit for anyone exploring the city.
#
# 2. **Reichstag Building:** The German Parliament building, famous for its stunning glass dome that offers panoramic views of Berlin. It's a blend of historic and modern architecture.
#
# 3. **Berlin Wall and East Side Gallery:** Visit the remnants of the Berlin Wall which divided the city. The East Side Gallery is a vibrant outdoor gallery featuring murals painted by artists from around the world.
#
# 4. **Holocaust Memorial:** The Memorial to the Murdered Jews of Europe is a poignant tribute to the victims of the Holocaust, with a unique maze of concrete slabs that visitors can walk through.
#
# 5. **Museum Island:** A UNESCO World Heritage site housing several world-renowned museums, including the Pergamon Museum and the Altes Museum, where you can explore art and artifacts from various periods.
#
# 6. **Berlin Cathedral (Berliner Dom):** A stunning 19th-century Protestant cathedral with an impressive dome. You can also climb up for breathtaking views of the city.
#
# 7. **Checkpoint Charlie:** Once a crossing point between East and West Berlin during the Cold War, it now serves as a historic site, complete with a replica of the original guardhouse and informative exhibitions.
#
# 8. **Potsdam and Sanssouci Palace:** Located just outside Berlin, Potsdam is known for its beautiful parks and palaces. Sanssouci Palace, the summer residence of Frederick the Great, is particularly magnificent.
#
# 9. **Alexanderplatz and the TV Tower (Fernsehturm):** A central square in Berlin, Alexanderplatz is home to the famous TV Tower, where you can ascend for spectacular views of the city.
#
# 10. **Kaiser Wilhelm Memorial Church:** A damaged church preserved as a memorial to the destruction of war and an extraordinary piece of architecture blending old and new.
#
# These attractions offer a mix of history, culture, art, and modernity, showcasing the diverse charm of Berlin. Make sure to include them in your travel plans!
# # User: Recommend some local dishes to try while I'm there.
#
# # TravelAgent: When in Berlin, you must try these local dishes to truly experience the city’s culinary scene:
#
# 1. **Currywurst:** A Berlin classic, this fast food dish features a steamed, then fried pork sausage (Bratwurst) sliced and topped with curry ketchup and curry powder, often served with fries.
#
# 2. **Buletten:** These are German meatballs, typically made from ground beef and seasoned with onions and spices. They can be served hot or cold, often accompanied by potato salad or bread.
#
# 3. **Sauerbraten:** A traditional pot roast, usually made from beef, marinated in a mixture of vinegar, water, and spices for several days before slow-cooking it. It’s often served with red cabbage and potato dumplings.
#
# 4. **Königsberger Klopse:** These are East Prussian meatballs made from minced meat, onions, eggs, and spices, served in a creamy white sauce with capers. They are typically accompanied by potatoes or rice.
#
# 5. **Spätzle:** A type of soft egg noodle that is common in German cuisine. You can enjoy it plain, or topped with cheese (Käsespätzle) and onions, similar to macaroni and cheese.
#
# 6. **Reibekuchen:** Also known as potato pancakes, these crispy fried cakes are made from grated potatoes and are often served with apple sauce or sour cream.
#
# 7. **Kartoffelsalat:** German potato salad can vary by region. In Berlin, it’s typically made with boiled potatoes, vinegar, onions, and mustard, served warm or cold as a side dish.
#
# 8. **Berliner Pfannkuchen:** These are jam-filled donuts (akin to jelly-filled donuts) that make for a sweet treat. Traditionally enjoyed during New Year’s and carnival season, you can find them year-round.
#
# 9. **Weißwurst:** A traditional Bavarian sausage made from minced veal and flavored with fresh herbs. It’s typically served with sweet mustard and pretzels.
#
# 10. **Schnitzel:** A breaded and fried meat cutlet (usually pork, veal, or chicken). The Berliner Schnitzel is often served with potato salad or fries.
#
# These dishes reflect the heart and soul of Berlin’s food culture, so be sure to sample them while you explore the city!
