# %% [markdown]
# # Example Sample Hotel and Flight Booker Agent
#
# This solution will help you book flight tickets and hotel.  The scenario is a trip London Heathrow LHR Feb 20th 2024 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel.

# %% [markdown]
# # Initialize the Azure AI Agent Service and get configuration information from **.env**
#
# ### **.env**
#
# Create a .env file
#
# **.env** contains the connection string of Azure AI Agent Service, the model used by AOAI, and the corresponding Google API Search service API, ENDPOINT, etc.
#
# - **AZURE_AI_AGENT_MODEL_DEPLOYMENT_NAME** = "Your Azure AI Agent Service Model Deployment Name"
#
# [**NOTE**] You will need a model with 100,000 Rate Limit (Tokens per minute)  Rate Limit of 600 (Request per minute)
#
#   You can get model in Azure AI Foundry - Model and Endpoint.
#
#
# - **AZURE_AI_AGENT_PROJECT_CONNECTION_STRING** = "Your Azure AI Agent Service Project Connection String"
#
#   You can get the project connection string in your project overview in  AI ​​Foundry Portal Screen.
#
# - **SERPAPI_SEARCH_API_KEY** = "Your SERPAPI Search API KEY"
# - **SERPAPI_SEARCH_ENDPOINT** = "Your SERPAPI Search Endpoint"
#
# To get the Model Deployment Name and Project Connection String of Azure AI Agent Service, you need to create Azure AI Agent Service. It is recommended to use [this template](https://portal.azure.com/#create/Microsoft.Template/uri/https%3A%2F%2Fraw.githubusercontent.com%2Ffosteramanda%2Fazure-agent-quickstart-templates%2Frefs%2Fheads%2Fmaster%2Fquickstarts%2Fmicrosoft.azure-ai-agent-service%2Fstandard-agent%2Fazuredeploy.json) to create it directly （***Note:*** Azure AI Agent Service is currently set in a limited region. It is recommended that you refer to [this link](https://learn.microsoft.com/en-us/azure/ai-services/agents/concepts/model-region-support) to set the region)
#
# Agent needs to access SERPAPI. It is recommended to register using [this link](https://serpapi.com/searches). After registration, you can obtain a unique API KEY and ENDPOINT

# %% [markdown]
# # Setup
#
# To run this notebook, you will need to make sure you've installed the required libraries by running `pip install -r requirements.txt`.

# %%
# !python.exe -m pip install --upgrade pip
# !pip uninstall -y semantic-kernel azure-ai-projects agent-framework-azure-ai azure-identity azure-core

# !pip install --upgrade semantic-kernel
# !pip install --upgrade azure-ai-projects
# !pip install --upgrade agent-framework-azure-ai
# !pip install --upgrade azure-identity azure-core
# Out:
# Requirement already satisfied: pip in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (25.1.1)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-25.3
# Found existing installation: semantic-kernel 1.38.0
# Uninstalling semantic-kernel-1.38.0:
#   Successfully uninstalled semantic-kernel-1.38.0
# Found existing installation: azure-ai-projects 2.0.0b2
# Uninstalling azure-ai-projects-2.0.0b2:
#   Successfully uninstalled azure-ai-projects-2.0.0b2
# Found existing installation: agent-framework-azure-ai 1.0.0b251114
# Uninstalling agent-framework-azure-ai-1.0.0b251114:
#   Successfully uninstalled agent-framework-azure-ai-1.0.0b251114
# Found existing installation: azure-identity 1.25.1
# Uninstalling azure-identity-1.25.1:
#   Successfully uninstalled azure-identity-1.25.1
# Found existing installation: azure-core 1.36.0
# Uninstalling azure-core-1.36.0:
#   Successfully uninstalled azure-core-1.36.0
# Collecting semantic-kernel
#   Using cached semantic_kernel-1.38.0-py3-none-any.whl.metadata (13 kB)
# Collecting azure-ai-projects>=1.0.0b12 (from semantic-kernel)
#   Using cached azure_ai_projects-2.0.0b2-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: azure-ai-agents>=1.2.0b3 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.2.0b5)
# Requirement already satisfied: aiohttp~=3.8 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (3.13.2)
# Requirement already satisfied: cloudevents~=1.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.12.0)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (2.11.10)
# Requirement already satisfied: pydantic-settings~=2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (2.12.0)
# Requirement already satisfied: defusedxml~=0.7 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (0.7.1)
# Collecting azure-identity>=1.13 (from semantic-kernel)
#   Using cached azure_identity-1.25.1-py3-none-any.whl.metadata (88 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (2.3.4)
# Requirement already satisfied: openai<2,>=1.98.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.109.1)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.14.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: prance<25.4.9,>=23.6.21 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (23.6.21.0)
# Requirement already satisfied: pybars4~=0.9 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (1.16.3)
# Requirement already satisfied: protobuf in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (5.29.5)
# Requirement already satisfied: typing-extensions>=4.13 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from semantic-kernel) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp~=3.8->semantic-kernel) (1.22.0)
# Requirement already satisfied: deprecation<3.0,>=2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: packaging in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from deprecation<3.0,>=2.0->cloudevents~=1.0->semantic-kernel) (25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jinja2~=3.1->semantic-kernel) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai<2,>=1.98.0->semantic-kernel) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2,>=1.98.0->semantic-kernel) (3.11)
# Requirement already satisfied: certifi in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2,>=1.98.0->semantic-kernel) (0.16.0)
# Requirement already satisfied: isodate in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.25.1)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: parse in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.28.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.32.5)
# Requirement already satisfied: rfc3339-validator in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.12.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.59b0)
# Requirement already satisfied: chardet>=3.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (0.18.16)
# Requirement already satisfied: six~=1.15 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (1.17.0)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic-kernel) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic-settings~=2.0->semantic-kernel) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.5.0)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.1)
# Requirement already satisfied: av<17.0.0,>=14.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (16.0.1)
# Requirement already satisfied: cryptography>=44.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (46.0.3)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (1.0.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiortc>=1.9.0->semantic-kernel) (25.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (2.8.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Collecting azure-core>=1.30.0 (from azure-ai-agents>=1.2.0b3->semantic-kernel)
#   Using cached azure_core-1.36.0-py3-none-any.whl.metadata (47 kB)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects>=1.0.0b12->semantic-kernel) (12.27.1)
# Requirement already satisfied: msal>=1.30.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from ruamel.yaml>=0.17.10->prance<25.4.9,>=23.6.21->semantic-kernel) (0.2.14)
# Requirement already satisfied: colorama in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from tqdm>4->openai<2,>=1.98.0->semantic-kernel) (0.4.6)
# Using cached semantic_kernel-1.38.0-py3-none-any.whl (894 kB)
# Using cached azure_ai_projects-2.0.0b2-py3-none-any.whl (234 kB)
# Using cached azure_core-1.36.0-py3-none-any.whl (213 kB)
# Using cached azure_identity-1.25.1-py3-none-any.whl (191 kB)
# Installing collected packages: azure-core, azure-ai-projects, azure-identity, semantic-kernel
#
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------------------------------------- 0/4 [azure-core]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    ---------- ----------------------------- 1/4 [azure-ai-projects]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    -------------------- ------------------- 2/4 [azure-identity]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ------------------------------ --------- 3/4 [semantic-kernel]
#    ---------------------------------------- 4/4 [semantic-kernel]
#
# Successfully installed azure-ai-projects-2.0.0b2 azure-core-1.36.0 azure-identity-1.25.1 semantic-kernel-1.38.0
# Requirement already satisfied: azure-ai-projects in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (2.0.0b2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects) (12.27.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects) (2.32.5)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects) (2025.11.12)
# Collecting agent-framework-azure-ai
#   Using cached agent_framework_azure_ai-1.0.0b251114-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: agent-framework-core in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.0.0b251114)
# Requirement already satisfied: azure-ai-projects>=2.0.0b1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (2.0.0b2)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (1.2.0b5)
# Requirement already satisfied: aiohttp in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-azure-ai) (3.13.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-ai-projects>=2.0.0b1->agent-framework-azure-ai) (12.27.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.32.5)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects>=2.0.0b1->agent-framework-azure-ai) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=2.0.0b1->agent-framework-azure-ai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=2.0.0b1->agent-framework-azure-ai) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2025.11.12)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (2.11.10)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (2.12.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (0.4.13)
# Requirement already satisfied: openai>=1.99.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (1.109.1)
# Requirement already satisfied: azure-identity<2,>=1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (1.25.1)
# Requirement already satisfied: mcp>=1.13 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.21.1)
# Requirement already satisfied: packaging>=24.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from agent-framework-core->agent-framework-azure-ai) (25.0)
# Requirement already satisfied: msal>=1.30.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework-azure-ai) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic<3,>=2->agent-framework-core->agent-framework-azure-ai) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pydantic-settings<3,>=2->agent-framework-core->agent-framework-azure-ai) (1.2.1)
# Requirement already satisfied: anyio>=4.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (4.25.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.49.3)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.38.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from anyio>=4.5->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (0.28.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (0.12.0)
# Requirement already satisfied: tqdm>4 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-api>=1.24->agent-framework-core->agent-framework-azure-ai) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core->agent-framework-azure-ai) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.66.2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework-azure-ai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from opentelemetry-sdk>=1.24->agent-framework-core->agent-framework-azure-ai) (0.59b0)
# Requirement already satisfied: colorama in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from tqdm>4->openai>=1.99.0->agent-framework-core->agent-framework-azure-ai) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework-azure-ai) (8.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from aiohttp->agent-framework-azure-ai) (1.22.0)
# Using cached agent_framework_azure_ai-1.0.0b251114-py3-none-any.whl (18 kB)
# Installing collected packages: agent-framework-azure-ai
# Successfully installed agent-framework-azure-ai-1.0.0b251114
# Requirement already satisfied: azure-identity in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (1.25.1)
# Requirement already satisfied: azure-core in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-identity) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from azure-core) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhost\onedrive\escritorio\github\ai-agents-for-beginners\.venv\lib\site-packages (from requests>=2.21.0->azure-core) (2025.11.12)

# %%
from semantic_kernel import __version__

__version__
# Out:
# '1.38.0'

# %% [markdown]
# Your Semantic Kernel version should be at least 1.27.2.

# %% [markdown]
# Load your .env file setting and resources please ensure you have added your keys and setting and created a local .env file.

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Log in to Azure
#
# You now need to log in to Azure. Open a terminal and run the following command:
#
# ```bash
# az login
# ```
#
# This command will prompt you to enter your Azure credentials, enabling the Azure AI Agent service to function correctly.

# %% [markdown]
# # Explanation:
# This is a variable that stores the API key for accessing a SERP (Search Engine Results Page) API service. An API key is a unique identifier used to authenticate requests associated with your account.
#
# Purpose: The purpose of this line is to store the API key in a variable so that it can be used to authenticate requests to the SERP API service. The API key is required to access the service and perform searches.
# How to Get a SERP API Key: To get a SERP API key, follow these general steps at https://serpapi.com (the exact steps may vary depending on the specific SERP API service you are using):
#
# Choose a SERP API Service: There are several SERP API services available, such as SerpAPI, Google Custom Search JSON API, and others. Choose the one that best fits your needs.
#
# Sign Up for an Account: Go to the website of the chosen SERP API service and sign up for an account. You may need to provide some basic information and verify your email address.
#
# Create an API Key: After signing up, log in to your account and navigate to the API section or dashboard. Look for an option to create or generate a new API key.
# Copy the API Key to your .env file.

# %%
import os

load_dotenv('../../.env')
SERP_API_KEY=os.environ.get("SERPAPI_SEARCH_API_KEY")

# %% [markdown]
# # Explanation:
# BASE_URL: This is a variable that stores the base URL for the SERP API endpoint. The variable name BASE_URL is a convention used to indicate that this URL is the starting point for making API requests.
# 'https://serpapi.com/search':
#
# This is the actual URL string assigned to the BASE_URL variable. It represents the endpoint for performing search queries using the SERP API.
#
# # Purpose:
# The purpose of this line is to define a constant that holds the base URL for the SERP API. This URL will be used as the starting point for constructing API requests to perform search operations.
#
# # Usage:
# By defining the base URL in a variable, you can easily reuse it throughout your code whenever you need to make requests to the SERP API. This makes your code more maintainable and reduces the risk of errors from hardcoding the URL in multiple places. The current example is https://serpapi.com/search?engine=bing which is using Bing search API. Different API can be selected at https://Serpapi.com

# %%
BASE_URL = 'https://serpapi.com/search?engine=bing'

# %% [markdown]
# # Explanation:
#
# This is where your plugin code is located.
#
# Class Definition: `class BookingPlugin`: Defines a class named BookingPlugin that contains methods for booking hotels and flights.
#
# Hotel Booking Method:
#
# - `@kernel_function(description="booking hotel")`: A decorator that describes the function as a kernel function for booking hotels.
# - `def booking_hotel(self, query: Annotated[str, "The name of the city"], check_in_date: Annotated[str, "Hotel Check-in Time"], check_out_date: Annotated[str, "Hotel Check-out Time"]) -> Annotated[str, "Return the result of booking hotel information"]:`: Defines a method for booking hotels with annotated parameters and return type.
#
# The method constructs a dictionary of parameters for the hotel booking request and sends a GET request to the SERP API. It checks the response status and returns the hotel properties if successful, or None if the request failed.
#
# Flight Booking Method:
#
# - `@kernel_function(description="booking flight")`: A decorator that describes the function as a kernel function for booking flights.
# - `def booking_flight(self, origin: Annotated[str, "The name of Departure"], destination: Annotated[str, "The name of Destination"], outbound_date: Annotated[str, "The date of outbound"], return_date: Annotated[str, "The date of Return_date"]) -> Annotated[str, "Return the result of booking flight information"]:`: Defines a method for booking flights with annotated parameters and return type.
#
# The method constructs dictionaries of parameters for the outbound and return flight requests and sends GET requests to the SERP API. It checks the response status and appends the flight information to the result string if successful, or prints an error message if the request failed. The method returns the result string containing the flight information.

# %%
import requests

from typing import Annotated

from semantic_kernel.functions import kernel_function

# Define Booking Plugin
class BookingPlugin:
    """Booking Plugin for customers"""

    @kernel_function(description="booking hotel")
    def booking_hotel(
        self, 
        query: Annotated[str, "The name of the city"], 
        check_in_date: Annotated[str, "Hotel Check-in Time"], 
        check_out_date: Annotated[str, "Hotel Check-out Time"],
    ) -> Annotated[str, "Return the result of booking hotel information"]:
        """
        Function to book a hotel.
        Parameters:
        - query: The name of the city
        - check_in_date: Hotel Check-in Time
        - check_out_date: Hotel Check-out Time
        Returns:
        - The result of booking hotel information
        """

        # Define the parameters for the hotel booking request
        params = {
            "engine": "google_hotels",
            "q": query,
            "check_in_date": check_in_date,
            "check_out_date": check_out_date,
            "adults": "1",
            "currency": "GBP",
            "gl": "uk",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request to the SERP API
        response = requests.get(BASE_URL, params=params)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the response content as JSON
            response = response.json()
            # Return the properties from the response
            return response["properties"]
        else:
            # Return None if the request failed
            return None

    @kernel_function(description="booking flight")
    def booking_flight(
        self, 
        origin: Annotated[str, "The name of Departure"], 
        destination: Annotated[str, "The name of Destination"], 
        outbound_date: Annotated[str, "The date of outbound"], 
        return_date: Annotated[str, "The date of Return_date"],
    ) -> Annotated[str, "Return the result of booking flight information"]:
        """
        Function to book a flight.
        Parameters:
        - origin: The name of Departure
        - destination: The name of Destination
        - outbound_date: The date of outbound
        - return_date: The date of Return_date
        - airline: The preferred airline carrier
        - hotel_brand: The preferred hotel brand
        Returns:
        - The result of booking flight information
        """
        
        # Define the parameters for the outbound flight request
        go_params = {
            "engine": "google_flights",
            "departure_id": "destination",
            "arrival_id": "origin",
            "outbound_date": "outbound_date",
            "return_date": "return_date",
            "currency": "GBP",
            "hl": "en",
            "airline": "airline",
            "hotel_brand": "hotel_brand",
            "api_key": "SERP_API_KEY"
        }
 
        print(go_params)

        # Send the GET request for the outbound flight
        go_response = requests.get(BASE_URL, params=go_params)

        # Initialize the result string
        result = ''

        # Check if the outbound flight request was successful
        if go_response.status_code == 200:
            # Parse the response content as JSON
            response = go_response.json()
            # Append the outbound flight information to the result
            result += "# outbound \n " + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Define the parameters for the return flight request
        back_params = {
            #"engine": "google_flights",
            "departure_id": destination,
            "arrival_id": origin,
            "outbound_date": outbound_date,
            "return_date": return_date,
            "currency": "GBP",
            "hl": "en",
            "api_key": SERP_API_KEY
        }

        # Send the GET request for the return flight
        back_response = requests.get(BASE_URL, params=back_params)

        # Check if the return flight request was successful
        if back_response.status_code == 200:
            # Parse the response content as JSON
            response = back_response.json()
            # Append the return flight information to the result
            result += "\n # return \n" + str(response)
        else:
            # Print an error message if the request failed
            print('error!!!')

        # Print the result
        print(result)

        # Return the result
        return result

# %% [markdown]
# # Explanation:
# Import Statements: Import necessary modules for Azure credentials, AI agent, chat message content, author role, and kernel function decorator.
#
# Asynchronous Context Manager: async with (DefaultAzureCredential() as creds, AzureAIAgent.create_client(credential=creds, conn_str="...") as client,): This sets up an asynchronous context manager to handle Azure credentials and create an AI agent client.
#
# Agent Name and Instructions:
# - `AGENT_NAME = "BookingAgent"`: Defines the name of the agent.
# - `AGENT_INSTRUCTIONS = """..."""`: Provides detailed instructions for the agent on how to handle booking requests.
#
# Create Agent Definition: `agent_definition = await client.agents.create_agent(...)`: Creates an agent definition with the specified model, name, and instructions.
#
# Create AzureAI Agent: `agent = AzureAIAgent(...)`: Creates an AzureAI agent using the client, agent definition, and the defined plugin.
#
# Create Thread: `thread: AzureAIAgentThread | None = None`: Create a thread for the agent. It isn't required to first create a thread - if the value of `None` is provided, a new thread will be created during the first invocation and returned as part of the response.
#
# User Inputs: `user_inputs = ["..."]`: Defines a list of user inputs for the agent to process.
#
# In the finally block, delete the thread and agent to clean up resources.

# %% [markdown]
# # Authentication
#
# The `DefaultAzureCredential` class is part of the Azure SDK for Python. It provides a default way to authenticate with Azure services. It attempts to authenticate using multiple methods in a specific order, such as environment variables, managed identity, and Azure CLI credentials.
#
# Asynchronous Operations: The aio module indicates that the DefaultAzureCredential class supports asynchronous operations. This means you can use it with asyncio to perform non-blocking authentication requests.

# %%
# Import necessary modules
from azure.identity.aio import DefaultAzureCredential
from semantic_kernel.agents import AzureAIAgent, AzureAIAgentSettings, AzureAIAgentThread

ai_agent_settings = AzureAIAgentSettings.create()

# Azure AI Setting
async with (
     DefaultAzureCredential() as creds,
    AzureAIAgent.create_client(
        credential=creds,
        conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
    ) as client,
):    
    
    # Define the agent's name and instructions
    AGENT_NAME = "BookingAgent"
    AGENT_INSTRUCTIONS = """
    You are a booking agent, help me to book flights or hotels.

    Thought: Understand the user's intention and confirm whether to use the reservation system to complete the task.

    Action:
    - If booking a flight, convert the departure name and destination name into airport codes.
    - If booking a hotel or flight, use the corresponding API to call. Ensure that the necessary parameters are available. If any parameters are missing, use default values or assumptions to proceed.
    - If it is not a hotel or flight booking, respond with the final answer only.
    - Output the results using a markdown table:
    - For flight bookings, separate the outbound and return contents and list them in the order of Departure_airport Name | Airline | Flight Number | Departure Time | Arrival_airport Name | Arrival Time | Duration | Airplane | Travel Class | Price (USD) | Legroom | Extensions | Carbon Emissions (kg).
    - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
    """

    # Create agent definition with the specified model, name, and instructions
    agent_definition = await client.agents.create_agent(
        model=ai_agent_settings.model_deployment_name,
        name=AGENT_NAME,
        instructions=AGENT_INSTRUCTIONS,
    )

    # Create the AzureAI Agent using the client and agent definition
    agent = AzureAIAgent(
        client=client,
        definition=agent_definition,
        plugins=[BookingPlugin()]
    )

    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: AzureAIAgentThread | None = None

    # This is your prompt for the activity or task you want to complete 
    # Define user inputs for the agent to process we have provided some example prompts to test and validate 
    user_inputs = [
        # "Can you tell me the round-trip air ticket from  London to New York JFK aiport, the departure time is February 17, 2025, and the return time is February 23, 2025"
        # "Book a hotel in New York from Feb 20,2025 to Feb 24,2025"
        "Help me book flight tickets and hotel for the following trip London Heathrow LHR Feb 20th 2025 to New York JFK returning Feb 27th 2025 flying economy with British Airways only. I want a stay in a Hilton hotel in New York please provide costs for the flight and hotel"
        # "I have a business trip from London LHR to New York JFK on Feb 20th 2025 to Feb 27th 2025, can you help me to book a hotel and flight tickets"
    ]

    try:
        # Process each user input
        for user_input in user_inputs:
            print(f"# User: '{user_input}'")
            # Get the agent's response for the specified thread
            response = await agent.get_response(
                messages=user_input,
                thread=thread,
            )
            thread = response.thread
            # Print the agent's response
            print(f"{response.name}: '{response.content}'")
    finally:
        # Clean up by deleting the thread and agent
        await thread.delete() if thread else None
        await client.agents.delete_agent(agent.id)
# Out:
# The create method is deprecated. Use the __new__ method instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 12
#       5 ai_agent_settings = AzureAIAgentSettings.create()
#       7 # Azure AI Setting
#       8 async with (
#       9      DefaultAzureCredential() as creds,
#      10     AzureAIAgent.create_client(
#      11         credential=creds,
# ---> 12         conn_str=ai_agent_settings.project_connection_string.get_secret_value(),
#      13     ) as client,
#      14 ):
#      15
#      16     # Define the agent's name and instructions
#      17     AGENT_NAME = "BookingAgent"
#      18     AGENT_INSTRUCTIONS = """
#      19     You are a booking agent, help me to book flights or hotels.
#      20
#    (...)     29     - For hotel bookings, list them in the order of Properties Name | Properties description | check_in_time | check_out_time | prices | nearby_places | hotel_class | gps_coordinates.
#      30     """
#
# File ~\OneDrive\Escritorio\Github\ai-agents-for-beginners\.venv\Lib\site-packages\pydantic\main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'AzureAIAgentSettings' object has no attribute 'project_connection_string'
